# %% [markdown]
# <a href="https://colab.research.google.com/github/ryanczhang7/spotifyproject/blob/master/Spotify_Data_Acquisition_Part_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Intro

# %% [markdown]
# **My original dataset contains only about 1050 observations, of which around 220 were lost when attempting to scrape lyrics, and 10 more were lost when querying personality analysis. Best case, I want many thousands of observations for a good model, not to mention I would like to use XGBoost and LightGBM effectively, both of which require large datasets. So getting observations in the hundreds of thousands would be optimal, as I doubt I could get a dataset with millions of observations. Another problem is that none of the data in my original dataset is time labelled, which is a problem since the target label popularity is likely highly influenced by the release date of a song.**

# %% [markdown]
# **Both of these problems are solved by this data set I found created by Andrew Thompson https://components.one/datasets/billboard-200/. It has 340,000 observations of tracks, and they all have time labels. I expect to lose many observations again when I scrape lyrics and query personality analysis, but I hope to have at least 100,000 when all is done. Also, my original dataset contains many unpopular album songs, some of which function as intros or interludes. These songs are all from the billboard 100, which may make them significantly better observations for the purpose of training a model to predict popularity. Ths dataset also has no null values. Currently, the Spotify Web API features missing that I need to query are popularity and explicit. Then I need to attempt to web scrape lyrics, and query sentiment analysis and personality analysis again. This will all take quite a while, given 340,000 observations. The data is in a database file.**

# %% [markdown]
# # Getting the table from SQL Database File

# %%
import sqlite3
import pandas as pd

db = sqlite3.connect('/content/drive/My Drive/billboard-200.db')
cursor = db.cursor()
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
tables = cursor.fetchall()
cursor.close()
db.close()

tables
# Out:
# [('albums',), ('acoustic_features',)]

# %%
# The table we want is the acoustic_features table
db = sqlite3.connect('/content/drive/My Drive/billboard-200.db')
spotify_df = pd.read_sql("SELECT * from acoustic_features", db)
spotify_df
# Out:
#                             id  ...        date
# 0       0Veyvc3n9AcLSoK3r1dA12  ...  2018-12-21
# 1       77JzXZonNumWsuXKy9vr3U  ...  2018-12-21
# 2       18yllZD0TdF7ykcREib8Z1  ...  2018-12-21
# 3       1wJRveJZLSb1rjhnUHQiv6  ...  2018-12-21
# 4       0jAfdqv18goRTUxm3ilRjb  ...  2018-12-21
# ...                        ...  ...         ...
# 339850  1EU8l9SctgP0gwIFxdjKPA  ...        1963
# 339851  4a0J3zWWe5IXdwWWQSypjq  ...        1963
# 339852  28VEEbzNdg6r5gQFY5wWI3  ...        1963
# 339853  7i3NXBP12BJoerk6sAATx0  ...        1963
# 339854  57j1v3ks11sygQuUWcSHaL  ...        1963
#
# [339855 rows x 19 columns]

# %%
# converting date feature to datetime object
spotify_df["date"] = pd.to_datetime(spotify_df["date"])
spotify_df["date"]
# Out:
# 0        2018-12-21
# 1        2018-12-21
# 2        2018-12-21
# 3        2018-12-21
# 4        2018-12-21
#             ...
# 339850   1963-01-01
# 339851   1963-01-01
# 339852   1963-01-01
# 339853   1963-01-01
# 339854   1963-01-01
# Name: date, Length: 339855, dtype: datetime64[ns]

# %%
# Saving to csv so I don't have to repeat above steps
spotify_df.to_csv('/content/drive/My Drive/spotify_df.csv', index=False)

# %% [markdown]
# # Querying the missing popularity and explicit features from Spotify Web API

# %%
spotify_df = pd.read_csv("/content/drive/My Drive/spotify_df.csv")

# %%
spotify_df
# Out:
#                             id  ...        date
# 0       0Veyvc3n9AcLSoK3r1dA12  ...  2018-12-21
# 1       77JzXZonNumWsuXKy9vr3U  ...  2018-12-21
# 2       18yllZD0TdF7ykcREib8Z1  ...  2018-12-21
# 3       1wJRveJZLSb1rjhnUHQiv6  ...  2018-12-21
# 4       0jAfdqv18goRTUxm3ilRjb  ...  2018-12-21
# ...                        ...  ...         ...
# 339850  1EU8l9SctgP0gwIFxdjKPA  ...  1963-01-01
# 339851  4a0J3zWWe5IXdwWWQSypjq  ...  1963-01-01
# 339852  28VEEbzNdg6r5gQFY5wWI3  ...  1963-01-01
# 339853  7i3NXBP12BJoerk6sAATx0  ...  1963-01-01
# 339854  57j1v3ks11sygQuUWcSHaL  ...  1963-01-01
#
# [339855 rows x 19 columns]

# %%
# Using spotipy package to interact with Spotify Web API
import spotipy

# To access authorised Spotify data
from spotipy.oauth2 import SpotifyClientCredentials

client_credentials_manager = SpotifyClientCredentials(
    client_id=client_id, client_secret=client_secret)
# Spotify object to access API
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
# Testing grabbing the popularity of a song
pop = sp.track(spotify_df.iloc[339854,0])
pop["popularity"]
# Out:
# 13

# %%
import time

# %%
# Grabbing popularity and explicit feature for each song

tracks = []

for uri in spotify_df["id"]:
  track_features = {}
  
  # grabbing popularity
  pop = sp.track(uri)
  track_features['popularity'] = pop['popularity']
  track_features['explicit'] = pop['explicit']
  tracks.append(track_features)
  time.sleep(0.1)

popularity = pd.json_normalize(tracks)
popularity

# %%
popularity = json_normalize(tracks)
popularity
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """Entry point for launching an IPython kernel.
#         popularity  explicit
# 0               58      True
# 1               59      True
# 2               57      True
# 3               83      True
# 4               71      True
# ...            ...       ...
# 240516          13     False
# 240517          15     False
# 240518          23     False
# 240519          27     False
# 240520          25     False
#
# [240521 rows x 2 columns]

# %%
spotify_df.iloc[240521:,0]
# Out:
# 240521    55QovqYXaR526sZWxnKQqz
# 240522    26AKvLdnRWa98vbOWJ2zfe
# 240523    1SxNgia01ERxRsFRcCu1yv
# 240524    3MN82VctKXwosPol8bzyDM
# 240525    1fKWRNMOMoG6NzaQwSkp9K
#                    ...
# 339850    1EU8l9SctgP0gwIFxdjKPA
# 339851    4a0J3zWWe5IXdwWWQSypjq
# 339852    28VEEbzNdg6r5gQFY5wWI3
# 339853    7i3NXBP12BJoerk6sAATx0
# 339854    57j1v3ks11sygQuUWcSHaL
# Name: id, Length: 99334, dtype: object

# %%
tracks = []

for uri in spotify_df.iloc[240521:,0]:
  track_features = {}
  
  # grabbing popularity
  pop = sp.track(uri)
  track_features['popularity'] = pop['popularity']
  track_features['explicit'] = pop['explicit']
  tracks.append(track_features)
  time.sleep(0.1)

popularity2 = json_normalize(tracks)
popularity2
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:15: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   from ipykernel import kernelapp as app
#        popularity  explicit
# 0              17     False
# 1              24     False
# 2              16     False
# 3              41     False
# 4              15     False
# ...           ...       ...
# 99329           9     False
# 99330           8     False
# 99331          10     False
# 99332          11     False
# 99333          13     False
#
# [99334 rows x 2 columns]

# %%
# I ended the first query early so I concatenate both dfs
popularity_complete = pd.concat([popularity, popularity2], ignore_index=True)

# %%
# The observations are in the same order as in the original dataset, and both 
# are 0 indexed, so I can merge by index.
spotify_df = spotify_df.merge(popularity_complete, left_index=True, 
                              right_index=True, how="outer")

# %%
spotify_df
# Out:
#                             id  ... explicit
# 0       0Veyvc3n9AcLSoK3r1dA12  ...     True
# 1       77JzXZonNumWsuXKy9vr3U  ...     True
# 2       18yllZD0TdF7ykcREib8Z1  ...     True
# 3       1wJRveJZLSb1rjhnUHQiv6  ...     True
# 4       0jAfdqv18goRTUxm3ilRjb  ...     True
# ...                        ...  ...      ...
# 339850  1EU8l9SctgP0gwIFxdjKPA  ...    False
# 339851  4a0J3zWWe5IXdwWWQSypjq  ...    False
# 339852  28VEEbzNdg6r5gQFY5wWI3  ...    False
# 339853  7i3NXBP12BJoerk6sAATx0  ...    False
# 339854  57j1v3ks11sygQuUWcSHaL  ...    False
#
# [339855 rows x 21 columns]

# %%
# Saving this complete audio features dataset to csv
spotify_df.to_csv("/content/drive/My Drive/spotify_audio.csv", index=False)

# %% [markdown]
# # Web Scraping lyrics off Metrolyrics

# %%
import requests
from bs4 import BeautifulSoup
import re
import string
import time

# %% [markdown]
# **Many of these artists below I will not be able to get lyrics for, like various artists, or sountrack, or original cast.**

# %%
spotify_df["artist"].value_counts()
# Out:
# Various Artists                     11578
# Soundtrack                           8260
# Original Cast                         888
# Original Broadway Cast Recording      855
# Elvis Presley                         772
#                                     ...
# Joe Dolce                               1
# John O'Banion                           1
# Juan Velez                              1
# Patrick Hernandez                       1
# Yipes                                   1
# Name: artist, Length: 8081, dtype: int64

# %%
# Make new column with just clean song names (without (feat ...), 
# and without - Live) using regex

spotify_df["song"] = spotify_df["song"].str.replace(r' \([^)]*\)', "")
spotify_df["song"] = spotify_df["song"].str.replace(r' - Live', "")
spotify_df["song"]
# Out:
# 0            Voices In My Head
# 1                       Beasty
# 2                     I Did It
# 3                      Swervin
# 4                   Startender
#                   ...
# 339850      It'S A Raggy Waltz
# 339851          King For A Day
# 339852         Castilian Drums
# 339853    Blue Rondo A La Turk
# 339854               Take Five
# Name: song, Length: 339855, dtype: object

# %%
spotify_df.to_csv("/content/drive/My Drive/spotify_audio.csv", index=False)

# %%
spotify_df = pd.read_csv("/content/drive/My Drive/spotify_audio.csv")
spotify_df
# Out:
#                             id                  song  ... popularity explicit
# 0       0Veyvc3n9AcLSoK3r1dA12     Voices In My Head  ...         58     True
# 1       77JzXZonNumWsuXKy9vr3U                Beasty  ...         59     True
# 2       18yllZD0TdF7ykcREib8Z1              I Did It  ...         57     True
# 3       1wJRveJZLSb1rjhnUHQiv6               Swervin  ...         83     True
# 4       0jAfdqv18goRTUxm3ilRjb            Startender  ...         71     True
# ...                        ...                   ...  ...        ...      ...
# 339850  1EU8l9SctgP0gwIFxdjKPA    It'S A Raggy Waltz  ...          9    False
# 339851  4a0J3zWWe5IXdwWWQSypjq        King For A Day  ...          8    False
# 339852  28VEEbzNdg6r5gQFY5wWI3       Castilian Drums  ...         10    False
# 339853  7i3NXBP12BJoerk6sAATx0  Blue Rondo A La Turk  ...         11    False
# 339854  57j1v3ks11sygQuUWcSHaL             Take Five  ...         13    False
#
# [339855 rows x 21 columns]

# %%
# Testing generating a url for metrolyrics from the dataframe columns
# An example of an url is below. Urls don't have any punctuation except -

songs = zip(spotify_df["artist"], spotify_df["song"])
url = "https://www.metrolyrics.com/"
a = list(songs)
# Making a list in the right order, including the lyrics string in between
b = a[0][1].split() + ["lyrics"] + a[0][0].split()
# Removing punctuation from each string in list
c = [c.translate(str.maketrans('', '', string.punctuation)) for c in b]
# Joining the list with a - between each string
d = "-".join(c).lower()
d += ".html"
url += d
url
# Out:
# 'https://www.metrolyrics.com/voices-in-my-head-lyrics-a-boogie-wit-da-hoodie.html'

# %%
# Testing grabbing lyrics for the url generated above.

content = requests.get(url)
soup = BeautifulSoup(content.content, 'html.parser')

# Metrolyrics has nice label "verse" for div, which makes scraping easy
a = soup.findAll("p", class_="verse")
# Song lyrics are text separated by html tags, so I join them with a space
c = " ".join([b.text for b in a])
# Removing verse labels, and adding spaces to \n for even spacing
d = re.sub(r'\[.*?\]', "", c).strip().replace("\n", " \n ").lower()
# Removing punctuation
e = d.translate(str.maketrans('', '', string.punctuation))
# Removing parentheses around any song lyrics
f = re.sub('[()]', '', e)
# Replacing multiple spaces with just one, this will be chain_lyrics
g = re.sub(r' +', " ", f)
# This will be the clean lyrics without \n
h = re.sub(r' +', " ", g.replace("\n", " "))
h
# Out:
# 'monstas gon tear it up all she ever wanted was my heart to hurt no attachments just a gucci purse she know im mad rich she think im usin her my diamonds mad rich they so rude to her and the way im actin is all due to her if i think she thottin im gon do it first im gon call my side bitch and we gon do the work she know im from highbridge my chain show through the shirt the feds locked my man up free montana damn all he ever wanted was his bands up they gave him 10 years for nothin keep your head up if any niggas start to fret nigga lay em out just listen to all my tracks cause i dont wanna do no interviews im not into that and i be feelin like im malcolm i got the x on my back and every nigga in the x can vouch for me thats a fact i dropped my first mixtape and yeah that shit ran laps by the time i dropped the bigger artist like seven million in plaques got too much gold im way too smart to leave my crib without straps and any nigga run up on us gon get hit like that and ima be like nigga started what i started skinny nigga with a patek and a pyrex any nigga could get embarrassed come and try it any nigga could get a bad bitch just go and buy shit i know i know youre just like all the bitches i know why do you know all the bitches i know i think were better off as rivals yeah i know i know why do you know all the bitches i know youre just like all the bitches i know youre just like all my fuckin rivals yeah and i know i know youre just like all the bitches i know insecure so you got that lipo i feel like im the rappin michael yeah i think im better off without you and you think i dont know about the things you do but i do all the same fuckin things you do we are both the same i am just like you yeah i know that you get in your feelings baby me too sometimes i swear i say some shit that i dont mean to i make you feel a type of way i make you evil when i was broke they used to treat me like im seethrough they killed my nigga quado in the projects and then they killed beasty free peewee i swear to god somebody better die next and if its one of my niggas nigga free me'

# %% [markdown]
# **Becuase of how long it takes to scrape these lyrics I will have to partition the spotify_df into multiple parts and scrape lyrics for each part.**

# %%
# Web scraping the lyrics for songs off of metrolyrics.com
# This is what I used for the original 1050 songs
songs = zip(spotify_df["artist"], spotify_df["song"])

song_lyrics = []
for song in songs:
  url = "https://www.metrolyrics.com/"
  # Dictionary for the song lyrics
  lyrics_dict = {}

  try:
    a = list(song)
    b = list(a)[1].split() + ["lyrics"] + list(a)[0].split()
    c = [c.translate(str.maketrans('', '', string.punctuation)) for c in b]
    d = "-".join(c).lower()
    d += ".html"
    url += d

    content = requests.get(url)
    soup = BeautifulSoup(content.content, 'html.parser')

    # Metrolyrics has nice label "verse" for div, which makes scraping easy
    a = soup.findAll("p", class_="verse")
    # Song lyrics are text separated by html tags, so I join them with a space
    c = " ".join([b.text for b in a])
    # Removing verse labels, and adding spaces to \n for even spacing
    d = re.sub(r'\[.*?\]', "", c).strip().replace("\n", " \n ").lower()
    # Removing punctuation
    e = d.translate(str.maketrans('', '', string.punctuation))
    # Removing parentheses around any song lyrics
    f = re.sub('[()]', '', e)
    # Replacing multiple spaces with just one, this will be chain_lyrics
    g = re.sub(r' +', " ", f)
    # This will be the clean lyrics without \n
    h = re.sub(r' +', " ", g.replace("\n", " "))
    lyrics_dict["chain_lyrics"] = g
    lyrics_dict["lyrics"] = h

    song_lyrics.append(lyrics_dict)

  # Try except, in case there is an problem with the scraping append empty dict
  except Exception as e:
    song_lyrics.append({})

    time.sleep(0.01)

# %%
# Saving progress so far
lyrics_df = pd.json_normalize(song_lyrics)
lyrics_df.to_csv("/content/drive/My Drive/lyrics_df.csv", index=False)

# %%
lyrics_df = pd.read_csv("/content/drive/My Drive/lyrics_df.csv")
lyrics_df
# Out:
#                                             chain_lyrics                                             lyrics
# 0      monstas gon tear it up all she ever wanted was...  monstas gon tear it up all she ever wanted was...
# 1      all that we know is the logos and hb \n the gl...  all that we know is the logos and hb the glock...
# 2      yeah i cant trust these bitches \n i dont got ...  yeah i cant trust these bitches i dont got no ...
# 3      uh \n yeah \n oh thats london on da track run ...  uh yeah oh thats london on da track run that s...
# 4      yeah shawty got ass she just got a tummy tuck ...  yeah shawty got ass she just got a tummy tuck ...
# ...                                                  ...                                                ...
# 99271  how many times have you cut only to feel the p...  how many times have you cut only to feel the p...
# 99272  close your eyes \n and just hear me sing \n on...  close your eyes and just hear me sing one last...
# 99273  and you say this aint living \n you say you ca...  and you say this aint living you say you cant ...
# 99274  a trail of tears beyond redemption \n just a w...  a trail of tears beyond redemption just a word...
# 99275  another rebel runs against the grain \n a lone...  another rebel runs against the grain a loner i...
#
# [99276 rows x 2 columns]

# %%
# Second partition
spotify_partition1 = spotify_df.iloc[99276:175000,:]
spotify_partition1

# %%
songs = zip(spotify_partition1["artist"], spotify_partition1["song"])

song_lyrics = []
for song in songs:
  url = "https://www.metrolyrics.com/"
  # Dictionary for the song lyrics
  lyrics_dict = {}

  try:
    a = list(song)
    b = list(a)[1].split() + ["lyrics"] + list(a)[0].split()
    c = [c.translate(str.maketrans('', '', string.punctuation)) for c in b]
    d = "-".join(c).lower()
    d += ".html"
    url += d

    content = requests.get(url)
    soup = BeautifulSoup(content.content, 'html.parser')

    # Metrolyrics has nice label "verse" for div, which makes scraping easy
    a = soup.findAll("p", class_="verse")
    # Song lyrics are text separated by html tags, so I join them with a space
    c = " ".join([b.text for b in a])
    # Removing verse labels, and adding spaces to \n for even spacing
    d = re.sub(r'\[.*?\]', "", c).strip().replace("\n", " \n ").lower()
    # Removing punctuation
    e = d.translate(str.maketrans('', '', string.punctuation))
    # Removing parentheses around any song lyrics
    f = re.sub('[()]', '', e)
    # Replacing multiple spaces with just one, this will be chain_lyrics
    g = re.sub(r' +', " ", f)
    # This will be the clean lyrics without \n
    h = re.sub(r' +', " ", g.replace("\n", " "))
    lyrics_dict["chain_lyrics"] = g
    lyrics_dict["lyrics"] = h

    song_lyrics.append(lyrics_dict)

  # Try except, in case there is an problem with the scraping append empty dict
  except Exception as e:
    song_lyrics.append({})

    time.sleep(0.01)

# %%
lyrics_df1 = pd.json_normalize(song_lyrics)
lyrics_df1
# Out:
#                                             chain_lyrics                                             lyrics
# 0
# 1
# 2      sitting alone in the cold of the night \n your...  sitting alone in the cold of the night youre t...
# 3      they say you are right \n i hope that im wrong...  they say you are right i hope that im wrong i ...
# 4      now there is a light \n in the dark some will ...  now there is a light in the dark some will say...
# ...                                                  ...                                                ...
# 75719
# 75720  shove me under you again \n i cant wait for th...  shove me under you again i cant wait for this ...
# 75721  i got somethin up my sleeve \n i know you will...  i got somethin up my sleeve i know you will co...
# 75722  lets go the day has come to an end \n the sun ...  lets go the day has come to an end the sun is ...
# 75723  well i know you dont know the reason \n and it...  well i know you dont know the reason and its c...
#
# [75724 rows x 2 columns]

# %%
# Concatenating first and second partition
lyrics_df = pd.concat([lyrics_df, lyrics_df1], ignore_index=True)
lyrics_df
# Out:
#                                              chain_lyrics                                             lyrics
# 0       monstas gon tear it up all she ever wanted was...  monstas gon tear it up all she ever wanted was...
# 1       all that we know is the logos and hb \n the gl...  all that we know is the logos and hb the glock...
# 2       yeah i cant trust these bitches \n i dont got ...  yeah i cant trust these bitches i dont got no ...
# 3       uh \n yeah \n oh thats london on da track run ...  uh yeah oh thats london on da track run that s...
# 4       yeah shawty got ass she just got a tummy tuck ...  yeah shawty got ass she just got a tummy tuck ...
# ...                                                   ...                                                ...
# 174995
# 174996  shove me under you again \n i cant wait for th...  shove me under you again i cant wait for this ...
# 174997  i got somethin up my sleeve \n i know you will...  i got somethin up my sleeve i know you will co...
# 174998  lets go the day has come to an end \n the sun ...  lets go the day has come to an end the sun is ...
# 174999  well i know you dont know the reason \n and it...  well i know you dont know the reason and its c...
#
# [175000 rows x 2 columns]

# %%
# Saving progress so far
lyrics_df.to_csv("/content/drive/My Drive/lyrics_df.csv", index=False)

# %%
lyrics_df = pd.read_csv("/content/drive/My Drive/lyrics_df.csv")
lyrics_df
# Out:
#                                              chain_lyrics                                             lyrics
# 0       monstas gon tear it up all she ever wanted was...  monstas gon tear it up all she ever wanted was...
# 1       all that we know is the logos and hb \n the gl...  all that we know is the logos and hb the glock...
# 2       yeah i cant trust these bitches \n i dont got ...  yeah i cant trust these bitches i dont got no ...
# 3       uh \n yeah \n oh thats london on da track run ...  uh yeah oh thats london on da track run that s...
# 4       yeah shawty got ass she just got a tummy tuck ...  yeah shawty got ass she just got a tummy tuck ...
# ...                                                   ...                                                ...
# 174995                                                NaN                                                NaN
# 174996  shove me under you again \n i cant wait for th...  shove me under you again i cant wait for this ...
# 174997  i got somethin up my sleeve \n i know you will...  i got somethin up my sleeve i know you will co...
# 174998  lets go the day has come to an end \n the sun ...  lets go the day has come to an end the sun is ...
# 174999  well i know you dont know the reason \n and it...  well i know you dont know the reason and its c...
#
# [175000 rows x 2 columns]

# %%
# The third partition
spotify_partition2 = spotify_df.iloc[175000:260000,:]
spotify_partition2
# Out:
#                             id              song  ... popularity explicit
# 175000  231g8oadCYb2JCKMHiWn0H      Natural Life  ...         39    False
# 175001  3AZAEuBA6XcDBN2OhoiIkd   Next To Nothing  ...         39    False
# 175002  4LrbjBe6pFbDCXQAyrTzhj             Water  ...         38    False
# 175003  4sSutqK9JRIqWDRBQ9zP9o              Home  ...         41    False
# 175004  4wWF9CU6X4RJCBlTxzyg9y             Phase  ...         38    False
# ...                        ...               ...  ...        ...      ...
# 259995  2f0auRvwTvwIN3ZGIFhd2d   Two Steps Ahead  ...          8    False
# 259996  0SBn7AOys0rceEKCgZoWNn     Into the Dark  ...          6    False
# 259997  2m33PlUf3Dd6e2slYKD5bM  Just a Boy Again  ...          7    False
# 259998  0jQzPkltxwUwpJeM6CQu0X          Poor Boy  ...          7    False
# 259999  7AvucF4ReGdZrXIvcA7V2Z     Still On Fire  ...         12    False
#
# [85000 rows x 21 columns]

# %%
songs = zip(spotify_partition2["artist"], spotify_partition2["song"])

song_lyrics = []
for song in songs:
  url = "https://www.metrolyrics.com/"
  # Dictionary for the song lyrics
  lyrics_dict = {}

  try:
    a = list(song)
    b = list(a)[1].split() + ["lyrics"] + list(a)[0].split()
    c = [c.translate(str.maketrans('', '', string.punctuation)) for c in b]
    d = "-".join(c).lower()
    d += ".html"
    url += d

    content = requests.get(url)
    soup = BeautifulSoup(content.content, 'html.parser')

    # Metrolyrics has nice label "verse" for div, which makes scraping easy
    a = soup.findAll("p", class_="verse")
    # Song lyrics are text separated by html tags, so I join them with a space
    c = " ".join([b.text for b in a])
    # Removing verse labels, and adding spaces to \n for even spacing
    d = re.sub(r'\[.*?\]', "", c).strip().replace("\n", " \n ").lower()
    # Removing punctuation
    e = d.translate(str.maketrans('', '', string.punctuation))
    # Removing parentheses around any song lyrics
    f = re.sub('[()]', '', e)
    # Replacing multiple spaces with just one, this will be chain_lyrics
    g = re.sub(r' +', " ", f)
    # This will be the clean lyrics without \n
    h = re.sub(r' +', " ", g.replace("\n", " "))
    lyrics_dict["chain_lyrics"] = g
    lyrics_dict["lyrics"] = h

    song_lyrics.append(lyrics_dict)

  # Try except, in case there is an problem with the scraping append empty dict
  except Exception as e:
    song_lyrics.append({})

    time.sleep(0.01)

# %%
lyrics_df2 = pd.json_normalize(song_lyrics)
lyrics_df2
# Out:
#                                             chain_lyrics                                             lyrics
# 0      hold still all of my life all of my time \n i ...  hold still all of my life all of my time i don...
# 1      beneath this wave \n i just cant take your bre...  beneath this wave i just cant take your breath...
# 2      whats all this talk of a notion \n id rather d...  whats all this talk of a notion id rather drin...
# 3      ive got a little red bow \n and i bought it fo...  ive got a little red bow and i bought it for y...
# 4      the light is dead in your eye \n so ill keep l...  the light is dead in your eye so ill keep livi...
# ...                                                  ...                                                ...
# 84995
# 84996
# 84997
# 84998
# 84999  im in love with everything that breaks the gri...  im in love with everything that breaks the gri...
#
# [85000 rows x 2 columns]

# %%
# Concatenating the third partition with the rest so far
lyrics_df = pd.concat([lyrics_df, lyrics_df2], ignore_index=True)
lyrics_df
# Out:
#                                              chain_lyrics                                             lyrics
# 0       monstas gon tear it up all she ever wanted was...  monstas gon tear it up all she ever wanted was...
# 1       all that we know is the logos and hb \n the gl...  all that we know is the logos and hb the glock...
# 2       yeah i cant trust these bitches \n i dont got ...  yeah i cant trust these bitches i dont got no ...
# 3       uh \n yeah \n oh thats london on da track run ...  uh yeah oh thats london on da track run that s...
# 4       yeah shawty got ass she just got a tummy tuck ...  yeah shawty got ass she just got a tummy tuck ...
# ...                                                   ...                                                ...
# 259995
# 259996
# 259997
# 259998
# 259999  im in love with everything that breaks the gri...  im in love with everything that breaks the gri...
#
# [260000 rows x 2 columns]

# %%
lyrics_df.to_csv("/content/drive/My Drive/lyrics_df.csv", index=False)

# %%
# The fourth partition
spotify_partition3 = spotify_df.iloc[260000:339855,:]
spotify_partition3
# Out:
#                             id                      song  ... popularity explicit
# 260000  4rdVZkDBpWvIEIu66TB1SL         Just Like the USA  ...         11    False
# 260001  4LFnLp1Lzudln0MowwORBF             Head Is Happy  ...          8    False
# 260002  3z2Lf3LyFBIw9uxm9pC4Pa   The Back Door to Heaven  ...          8    False
# 260003  7HT6ZXnDZikE5HSQRL0Efj  All I Need Is Everything  ...         14    False
# 260004  0nk1mWP7jcCa5591QFVckI    Backwards and Forwards  ...          9    False
# ...                        ...                       ...  ...        ...      ...
# 339850  1EU8l9SctgP0gwIFxdjKPA        It'S A Raggy Waltz  ...          9    False
# 339851  4a0J3zWWe5IXdwWWQSypjq            King For A Day  ...          8    False
# 339852  28VEEbzNdg6r5gQFY5wWI3           Castilian Drums  ...         10    False
# 339853  7i3NXBP12BJoerk6sAATx0      Blue Rondo A La Turk  ...         11    False
# 339854  57j1v3ks11sygQuUWcSHaL                 Take Five  ...         13    False
#
# [79855 rows x 21 columns]

# %%
songs = zip(spotify_partition3["artist"], spotify_partition3["song"])

song_lyrics = []
for song in songs:
  url = "https://www.metrolyrics.com/"
  # Dictionary for the song lyrics
  lyrics_dict = {}

  try:
    a = list(song)
    b = list(a)[1].split() + ["lyrics"] + list(a)[0].split()
    c = [c.translate(str.maketrans('', '', string.punctuation)) for c in b]
    d = "-".join(c).lower()
    d += ".html"
    url += d

    content = requests.get(url)
    soup = BeautifulSoup(content.content, 'html.parser')

    # Metrolyrics has nice label "verse" for div, which makes scraping easy
    a = soup.findAll("p", class_="verse")
    # Song lyrics are text separated by html tags, so I join them with a space
    c = " ".join([b.text for b in a])
    # Removing verse labels, and adding spaces to \n for even spacing
    d = re.sub(r'\[.*?\]', "", c).strip().replace("\n", " \n ").lower()
    # Removing punctuation
    e = d.translate(str.maketrans('', '', string.punctuation))
    # Removing parentheses around any song lyrics
    f = re.sub('[()]', '', e)
    # Replacing multiple spaces with just one, this will be chain_lyrics
    g = re.sub(r' +', " ", f)
    # This will be the clean lyrics without \n
    h = re.sub(r' +', " ", g.replace("\n", " "))
    lyrics_dict["chain_lyrics"] = g
    lyrics_dict["lyrics"] = h

    song_lyrics.append(lyrics_dict)

  # Try except, in case there is an problem with the scraping append empty dict
  except Exception as e:
    song_lyrics.append({})

    time.sleep(0.01)

# %%
lyrics_df3 = pd.json_normalize(song_lyrics)
lyrics_df3
# Out:
#                                             chain_lyrics                                             lyrics
# 0
# 1      i recall the biggest beach \n throwing stones ...  i recall the biggest beach throwing stones alm...
# 2      my eyes are stuck on sleepless dreams \n this ...  my eyes are stuck on sleepless dreams this wor...
# 3      tears \n just like the jewels adorn their corp...  tears just like the jewels adorn their corpora...
# 4
# ...                                                  ...                                                ...
# 79850  instrumental \n fidel girl tv chiuso bluetooth...  instrumental fidel girl tv chiuso bluetooth fs...
# 79851
# 79852
# 79853
# 79854
#
# [79855 rows x 2 columns]

# %%
# Concatenating the 4th partition with the rest
lyrics_df = pd.concat([lyrics_df, lyrics_df3], ignore_index=True)
lyrics_df
# Out:
#                                              chain_lyrics                                             lyrics
# 0       monstas gon tear it up all she ever wanted was...  monstas gon tear it up all she ever wanted was...
# 1       all that we know is the logos and hb \n the gl...  all that we know is the logos and hb the glock...
# 2       yeah i cant trust these bitches \n i dont got ...  yeah i cant trust these bitches i dont got no ...
# 3       uh \n yeah \n oh thats london on da track run ...  uh yeah oh thats london on da track run that s...
# 4       yeah shawty got ass she just got a tummy tuck ...  yeah shawty got ass she just got a tummy tuck ...
# ...                                                   ...                                                ...
# 339850  instrumental \n fidel girl tv chiuso bluetooth...  instrumental fidel girl tv chiuso bluetooth fs...
# 339851
# 339852
# 339853
# 339854
#
# [339855 rows x 2 columns]

# %%
# Saving progress again
lyrics_df.to_csv("/content/drive/My Drive/lyrics_df.csv", index=False)

# %%
# Merging the two dfs together. They are in the same order, so I can merge by index
spotify_df = spotify_df.merge(lyrics_df, left_index=True, right_index=True,
                              how='outer')
spotify_df
# Out:
#                             id  ...                                             lyrics
# 0       0Veyvc3n9AcLSoK3r1dA12  ...  monstas gon tear it up all she ever wanted was...
# 1       77JzXZonNumWsuXKy9vr3U  ...  all that we know is the logos and hb the glock...
# 2       18yllZD0TdF7ykcREib8Z1  ...  yeah i cant trust these bitches i dont got no ...
# 3       1wJRveJZLSb1rjhnUHQiv6  ...  uh yeah oh thats london on da track run that s...
# 4       0jAfdqv18goRTUxm3ilRjb  ...  yeah shawty got ass she just got a tummy tuck ...
# ...                        ...  ...                                                ...
# 339850  1EU8l9SctgP0gwIFxdjKPA  ...  instrumental fidel girl tv chiuso bluetooth fs...
# 339851  4a0J3zWWe5IXdwWWQSypjq  ...
# 339852  28VEEbzNdg6r5gQFY5wWI3  ...
# 339853  7i3NXBP12BJoerk6sAATx0  ...
# 339854  57j1v3ks11sygQuUWcSHaL  ...
#
# [339855 rows x 23 columns]

# %%
spotify_df = pd.read_csv("/content/drive/My Drive/spotify_lyrics.csv")
spotify_df
# Out:
#                             id  ...                                             lyrics
# 0       0Veyvc3n9AcLSoK3r1dA12  ...  monstas gon tear it up all she ever wanted was...
# 1       77JzXZonNumWsuXKy9vr3U  ...  all that we know is the logos and hb the glock...
# 2       18yllZD0TdF7ykcREib8Z1  ...  yeah i cant trust these bitches i dont got no ...
# 3       1wJRveJZLSb1rjhnUHQiv6  ...  uh yeah oh thats london on da track run that s...
# 4       0jAfdqv18goRTUxm3ilRjb  ...  yeah shawty got ass she just got a tummy tuck ...
# ...                        ...  ...                                                ...
# 339850  1EU8l9SctgP0gwIFxdjKPA  ...  instrumental fidel girl tv chiuso bluetooth fs...
# 339851  4a0J3zWWe5IXdwWWQSypjq  ...                                                NaN
# 339852  28VEEbzNdg6r5gQFY5wWI3  ...                                                NaN
# 339853  7i3NXBP12BJoerk6sAATx0  ...                                                NaN
# 339854  57j1v3ks11sygQuUWcSHaL  ...                                                NaN
#
# [339855 rows x 23 columns]

# %%
# Seeing how many songs I managed to get lyrics for. I will only keep those.
# Without lyrics I cannot get sentiment or personality analysis.
spotify_df[spotify_df["lyrics"].notnull()]
# Out:
#                             id  ...                                             lyrics
# 0       0Veyvc3n9AcLSoK3r1dA12  ...  monstas gon tear it up all she ever wanted was...
# 1       77JzXZonNumWsuXKy9vr3U  ...  all that we know is the logos and hb the glock...
# 2       18yllZD0TdF7ykcREib8Z1  ...  yeah i cant trust these bitches i dont got no ...
# 3       1wJRveJZLSb1rjhnUHQiv6  ...  uh yeah oh thats london on da track run that s...
# 4       0jAfdqv18goRTUxm3ilRjb  ...  yeah shawty got ass she just got a tummy tuck ...
# ...                        ...  ...                                                ...
# 339840  0YUgXm3g2TozRf8aAJSs7w  ...  whether you are here or yonder whether you are...
# 339841  3VWyVAx1aIJwzt1Q7eOeqf  ...  its very clear our love is here to stay not fo...
# 339842  26opStezaJhoYXFcGSnruX  ...  love is for the warm and willing waiting for t...
# 339843  2AQMj428TntnVZW9ngkxUG  ...  أنا شعري غامق بس قلبي مطقطق ابيض من زمان جايز ...
# 339850  1EU8l9SctgP0gwIFxdjKPA  ...  instrumental fidel girl tv chiuso bluetooth fs...
#
# [144634 rows x 23 columns]

# %%
spotify_df = spotify_df[spotify_df["lyrics"].notnull()]
spotify_df = spotify_df.reset_index().iloc[:,1:]
spotify_df
# Out:
#                             id  ...                                             lyrics
# 0       0Veyvc3n9AcLSoK3r1dA12  ...  monstas gon tear it up all she ever wanted was...
# 1       77JzXZonNumWsuXKy9vr3U  ...  all that we know is the logos and hb the glock...
# 2       18yllZD0TdF7ykcREib8Z1  ...  yeah i cant trust these bitches i dont got no ...
# 3       1wJRveJZLSb1rjhnUHQiv6  ...  uh yeah oh thats london on da track run that s...
# 4       0jAfdqv18goRTUxm3ilRjb  ...  yeah shawty got ass she just got a tummy tuck ...
# ...                        ...  ...                                                ...
# 144629  0YUgXm3g2TozRf8aAJSs7w  ...  whether you are here or yonder whether you are...
# 144630  3VWyVAx1aIJwzt1Q7eOeqf  ...  its very clear our love is here to stay not fo...
# 144631  26opStezaJhoYXFcGSnruX  ...  love is for the warm and willing waiting for t...
# 144632  2AQMj428TntnVZW9ngkxUG  ...  أنا شعري غامق بس قلبي مطقطق ابيض من زمان جايز ...
# 144633  1EU8l9SctgP0gwIFxdjKPA  ...  instrumental fidel girl tv chiuso bluetooth fs...
#
# [144634 rows x 23 columns]

# %%
# Saving my progress
spotify_df.to_csv("/content/drive/My Drive/spotify_lyrics.csv", index=False)

# %% [markdown]
# # Sentiment Analysis from Google Cloud Natural Language API

# %%
spotify_df = pd.read_csv("/content/drive/My Drive/spotify_lyrics.csv")
spotify_df.head()

# %%
spotify_partition = spotify_df.iloc[:50000,:]
spotify_partition.head()
# Out:
#                        id  ...                                             lyrics
# 0  0Veyvc3n9AcLSoK3r1dA12  ...  monstas gon tear it up all she ever wanted was...
# 1  77JzXZonNumWsuXKy9vr3U  ...  all that we know is the logos and hb the glock...
# 2  18yllZD0TdF7ykcREib8Z1  ...  yeah i cant trust these bitches i dont got no ...
# 3  1wJRveJZLSb1rjhnUHQiv6  ...  uh yeah oh thats london on da track run that s...
# 4  0jAfdqv18goRTUxm3ilRjb  ...  yeah shawty got ass she just got a tummy tuck ...
#
# [5 rows x 23 columns]

# %%
# Grabbing sentiment analysis or lyrics from Google Cloud Natural Language API.
# The rate limit is 600 requests per minute which is 10 requests per second
from googleapiclient.discovery import build
lservice = build('language', 'v1beta1', developerKey=APIKEY)

def sentiment(df):
  sentiments = []
  for lyric in df["lyrics"]:
    sentiment = {}

    try:
      response = lservice.documents().analyzeSentiment(
        body={
          'document': {
            'type': 'PLAIN_TEXT',
            'content': lyric
          }
        }).execute()
      sentiment["polarity"] = response['documentSentiment']['polarity']
      sentiment["magnitude"] = response['documentSentiment']['magnitude']
      sentiments.append(sentiment)

    except Exception as e:
      sentiments.append({})

    time.sleep(0.075)
  return sentiments

# %%
sentiments1 = pd.json_normalize(sentiment(spotify_partition))
sentiments1
# Out:
#        polarity  magnitude
# 0          -1.0        1.4
# 1           0.0        1.5
# 2          -1.0        1.9
# 3           0.5        1.4
# 4          -1.0        2.5
# ...         ...        ...
# 49995       1.0        0.1
# 49996       1.0        0.4
# 49997       1.0        0.8
# 49998      -1.0        0.5
# 49999      -1.0        0.8
#
# [50000 rows x 2 columns]

# %%
spotify_partition2 = spotify_df.iloc[50000:100000,:]
spotify_partition2.head()
# Out:
#                            id  ...                                             lyrics
# 50000  3o2PfltEMN9yrK0O7BTZia  ...  so tell me where it hurts do those stunts prov...
# 50001  4rq5wYypPiZMTl0mB3fGah  ...  and what you found was gold as black as dried ...
# 50002  5x1B2VxlxDm0HMJbQN9Vzw  ...  what this world needs is not another one hit w...
# 50003  7gO6lB3vqU96BPwhvVCJG5  ...  im the man with all ive ever wanted all the to...
# 50004  3GkIRSRXThXbSfQTKcMApx  ...  be careful little eyes what you see its the se...
#
# [5 rows x 23 columns]

# %%
sentiments2 = pd.json_normalize(sentiment(spotify_partition2))
sentiments2
# Out:
#        polarity  magnitude
# 0          -1.0        0.8
# 1          -1.0        0.4
# 2           1.0        1.1
# 3           0.1        1.0
# 4           0.1        1.4
# ...         ...        ...
# 49995       1.0        0.2
# 49996       1.0        1.1
# 49997      -1.0        0.4
# 49998       1.0        0.8
# 49999       1.0        0.3
#
# [50000 rows x 2 columns]

# %%
sentiments_df = pd.concat([sentiments1, sentiments2], ignore_index=True)

# %%
sentiments_df.to_csv("/content/drive/My Drive/sentiments.csv", index=False)

# %%
spotify_partition3 = spotify_df.iloc[100000:,:]

# %%
sentiments3 = pd.json_normalize(sentiment(spotify_partition3))

# %%
sentiments_df = pd.concat([sentiments_df, sentiments3], ignore_index=True)
sentiments_df
# Out:
#         polarity  magnitude
# 0           -1.0        1.4
# 1            0.0        1.5
# 2           -1.0        1.9
# 3            0.5        1.4
# 4           -1.0        2.5
# ...          ...        ...
# 144629       1.0        0.1
# 144630       1.0        0.8
# 144631       1.0        0.5
# 144632       NaN        NaN
# 144633      -1.0        0.4
#
# [144634 rows x 2 columns]

# %%
spotify_df = spotify_df.merge(sentiments_df, left_index=True, right_index=True,
                              how="outer")
spotify_df
# Out:
#                             id                  song  ... polarity magnitude
# 0       0Veyvc3n9AcLSoK3r1dA12     Voices In My Head  ...     -1.0       1.4
# 1       77JzXZonNumWsuXKy9vr3U                Beasty  ...      0.0       1.5
# 2       18yllZD0TdF7ykcREib8Z1              I Did It  ...     -1.0       1.9
# 3       1wJRveJZLSb1rjhnUHQiv6               Swervin  ...      0.5       1.4
# 4       0jAfdqv18goRTUxm3ilRjb            Startender  ...     -1.0       2.5
# ...                        ...                   ...  ...      ...       ...
# 144629  0YUgXm3g2TozRf8aAJSs7w    More Than You Know  ...      1.0       0.1
# 144630  3VWyVAx1aIJwzt1Q7eOeqf  Love Is Here to Stay  ...      1.0       0.8
# 144631  26opStezaJhoYXFcGSnruX      Warm and Willing  ...      1.0       0.5
# 144632  2AQMj428TntnVZW9ngkxUG       St. Louis Blues  ...      NaN       NaN
# 144633  1EU8l9SctgP0gwIFxdjKPA    It'S A Raggy Waltz  ...     -1.0       0.4
#
# [144634 rows x 25 columns]

# %%
# I drop whatever rows I didn't get sentiment analysis for
spotify_df = spotify_df[spotify_df["polarity"].notnull()]
spotify_df = spotify_df.reset_index().iloc[:,1:]
spotify_df
# Out:
#                             id                  song  ... polarity magnitude
# 0       0Veyvc3n9AcLSoK3r1dA12     Voices In My Head  ...     -1.0       1.4
# 1       77JzXZonNumWsuXKy9vr3U                Beasty  ...      0.0       1.5
# 2       18yllZD0TdF7ykcREib8Z1              I Did It  ...     -1.0       1.9
# 3       1wJRveJZLSb1rjhnUHQiv6               Swervin  ...      0.5       1.4
# 4       0jAfdqv18goRTUxm3ilRjb            Startender  ...     -1.0       2.5
# ...                        ...                   ...  ...      ...       ...
# 144367  2DJpoS75CjnHOTXSBPKBTn  My One and Only Love  ...      1.0       0.9
# 144368  0YUgXm3g2TozRf8aAJSs7w    More Than You Know  ...      1.0       0.1
# 144369  3VWyVAx1aIJwzt1Q7eOeqf  Love Is Here to Stay  ...      1.0       0.8
# 144370  26opStezaJhoYXFcGSnruX      Warm and Willing  ...      1.0       0.5
# 144371  1EU8l9SctgP0gwIFxdjKPA    It'S A Raggy Waltz  ...     -1.0       0.4
#
# [144372 rows x 25 columns]

# %%
# Saving progress
spotify_df.to_csv("/content/drive/My Drive/spotify_sentiment.csv", index=False)

# %% [markdown]
# # Personality Insights from IBM Watson Cloud API

# %%
spotify_df = pd.read_csv("/content/drive/My Drive/spotify_sentiment.csv")
spotify_df
# Out:
#                             id                  song  ... polarity magnitude
# 0       0Veyvc3n9AcLSoK3r1dA12     Voices In My Head  ...     -1.0       1.4
# 1       77JzXZonNumWsuXKy9vr3U                Beasty  ...      0.0       1.5
# 2       18yllZD0TdF7ykcREib8Z1              I Did It  ...     -1.0       1.9
# 3       1wJRveJZLSb1rjhnUHQiv6               Swervin  ...      0.5       1.4
# 4       0jAfdqv18goRTUxm3ilRjb            Startender  ...     -1.0       2.5
# ...                        ...                   ...  ...      ...       ...
# 144367  2DJpoS75CjnHOTXSBPKBTn  My One and Only Love  ...      1.0       0.9
# 144368  0YUgXm3g2TozRf8aAJSs7w    More Than You Know  ...      1.0       0.1
# 144369  3VWyVAx1aIJwzt1Q7eOeqf  Love Is Here to Stay  ...      1.0       0.8
# 144370  26opStezaJhoYXFcGSnruX      Warm and Willing  ...      1.0       0.5
# 144371  1EU8l9SctgP0gwIFxdjKPA    It'S A Raggy Waltz  ...     -1.0       0.4
#
# [144372 rows x 25 columns]

# %%
pip install --upgrade "ibm-watson>=4.3.0"

# %%
from ibm_watson import PersonalityInsightsV3
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator
# Authenticator object
authenticator = IAMAuthenticator(APIKEY)
personality_insights = PersonalityInsightsV3(
    version= '2017-10-13',
    authenticator=authenticator
)

personality_insights.set_service_url(
    "https://api.eu-gb.personality-insights.watson.cloud.ibm.com"
    "/instances/168b15d9-dd14-4832-bf98-0b304c149a6c")

# %%
# Grabbing the 17 chosen personality traits for each lyric
from ibm_watson import ApiException

def personality_q(df):
  personality = []

  for lyric in df["lyrics"]:
    traits = {}

    try:
      profile = personality_insights.profile(
            lyric,
            accept='application/json',
            content_type='text/html',
      ).get_result()["personality"]

      traits["artistic"] = profile[0]["children"][1]["percentile"]
      traits["emotion"] = profile[0]["children"][2]["percentile"]
      traits["imagination"] = profile[0]["children"][3]["percentile"]
      traits["defiance"] = profile[0]["children"][5]["percentile"]

      traits["assertive"] = profile[2]["children"][1]["percentile"]
      traits["cheerful"] = profile[2]["children"][2]["percentile"]
      traits["outgoing"] = profile[2]["children"][4]["percentile"]
      traits["gregarious"] = profile[2]["children"][5]["percentile"]

      traits["modesty"] = profile[3]["children"][2]["percentile"]
      traits["stubborn"] = profile[3]["children"][3]["percentile"]
      traits["sympathy"] = profile[3]["children"][4]["percentile"]
      traits["trust"] = profile[3]["children"][5]["percentile"]

      traits["fiery"] = profile[4]["children"][0]["percentile"]
      traits["melancholy"] = profile[4]["children"][2]["percentile"]
      traits["immoderation"] = profile[4]["children"][3]["percentile"]
      traits["self-conscious"] = profile[4]["children"][4]["percentile"]
      traits["stress"] = profile[4]["children"][5]["percentile"]

      personality.append(traits)

    # To continue the program if an ApiException occurrs. Will append an empty 
    # dictionary. The API requires at least 100 tokens to do an analysis, which
    # not all my lyrics might contain.
    except ApiException:
      personality.append({})

  return pd.json_normalize(personality)

# %%
spotify_partition1 = spotify_df.iloc[:101,:]

# %%
personality1 = personality_q(spotify_partition1)
personality1
# Out:
#      artistic   emotion  imagination  ...  immoderation  self-conscious    stress
# 0    0.983429  0.269785     0.845684  ...      0.587846        0.719468  0.480640
# 1    0.951363  0.118000     0.993211  ...      0.801688        0.390560  0.443472
# 2    0.974373  0.406747     0.700611  ...      0.450389        0.736179  0.669987
# 3    0.945732  0.312331     0.866823  ...      0.532799        0.075188  0.109408
# 4    0.921820  0.017407     0.824431  ...      0.610249        0.098895  0.122751
# ..        ...       ...          ...  ...           ...             ...       ...
# 96   0.930622  0.745394     0.551028  ...      0.380692        0.220633  0.303700
# 97   0.449456  0.920349     0.813274  ...      0.634973        0.161767  0.743967
# 98   0.904845  0.849844     0.973929  ...      0.577869        0.428962  0.237743
# 99   0.929041  0.771477     0.189124  ...      0.347495        0.047869  0.311686
# 100  0.666062  0.349670     0.656356  ...      0.230329        0.004321  0.013152
#
# [101 rows x 17 columns]

# %%
spotify_partition2 = spotify_df.iloc[101:998,:]

# %%
personality2 = personality_q(spotify_partition2)
personality2

# %%
personality = pd.concat([personality1, personality2], ignore_index=True)
personality
# Out:
#      artistic   emotion  imagination  ...  immoderation  self-conscious    stress
# 0    0.983429  0.269785     0.845684  ...      0.587846        0.719468  0.480640
# 1    0.951363  0.118000     0.993211  ...      0.801688        0.390560  0.443472
# 2    0.974373  0.406747     0.700611  ...      0.450389        0.736179  0.669987
# 3    0.945732  0.312331     0.866823  ...      0.532799        0.075188  0.109408
# 4    0.921820  0.017407     0.824431  ...      0.610249        0.098895  0.122751
# ..        ...       ...          ...  ...           ...             ...       ...
# 993  0.979987  0.313413     0.271619  ...      0.594996        0.667395  0.480486
# 994  0.999469  0.941313     0.989057  ...      0.590078        0.177969  0.354906
# 995  0.988905  0.937101     0.741063  ...      0.060687        0.222354  0.479499
# 996  0.482493  0.502376     0.009660  ...      0.941278        0.282183  0.474742
# 997  0.968380  0.294699     0.981385  ...      0.989313        0.981263  0.985129
#
# [998 rows x 17 columns]

# %%
spotify_partition3 = spotify_df.iloc[998:1998,:]

# %%
personality3 = personality_q(spotify_partition3)

# %%
personality = pd.concat([personality, personality3], ignore_index=True)
personality

# %%
personality = pd.read_csv("/content/drive/My Drive/personality.csv")
personality = personality.iloc[:,1:]
personality
# Out:
#       artistic   emotion  imagination  ...  immoderation  self-conscious    stress
# 0     0.983429  0.269785     0.845684  ...      0.587846        0.719468  0.480640
# 1     0.951363  0.118000     0.993211  ...      0.801688        0.390560  0.443472
# 2     0.974373  0.406747     0.700611  ...      0.450389        0.736179  0.669987
# 3     0.945732  0.312331     0.866823  ...      0.532799        0.075188  0.109408
# 4     0.921820  0.017407     0.824431  ...      0.610249        0.098895  0.122751
# ...        ...       ...          ...  ...           ...             ...       ...
# 1993  0.966506  0.999384     0.833097  ...      0.639104        0.983790  0.995672
# 1994  0.999762  0.999935     0.797607  ...      0.444600        0.869222  0.872836
# 1995  0.947925  0.997601     0.660800  ...      0.376898        0.805171  0.958301
# 1996  0.890352  0.746394     0.298913  ...      0.867095        0.145551  0.251402
# 1997  0.989761  0.969998     0.893499  ...      0.865483        0.627648  0.851726
#
# [1998 rows x 17 columns]

# %%
spotify_partition4 = spotify_df.iloc[1998:2998,:]
spotify_partition4
# Out:
#                           id               song  ... polarity magnitude
# 1998  3d1qN7AHge6BXuVPutcpI5         Some Of It  ...      0.3       0.8
# 1999  55UCRHfezMCFfbGy0tfjTG           Monsters  ...     -0.3       0.8
# 2000  1vHeu2j2MpfMqqvcXKLtic      Desperate Man  ...     -1.0       0.6
# 2001  7KNrJiivZDZuTNfZ7kDMdA  Jukebox And A Bar  ...     -1.0       0.8
# 2002  3uWC9e2W0qKahn2TtjLEH4      I Know Better  ...     -1.0       1.6
# ...                      ...                ...  ...      ...       ...
# 2993  6NvFnHaFXUttOycsNjD0YM           Doomsday  ...     -1.0       1.0
# 2994  1yXFAwSMDZmX2ZyDLLyQ9s        Almost Love  ...      1.0       0.9
# 2995  359HNzfOXhCMHB1pNKhyfH              Paris  ...      1.0       1.0
# 2996  72DnQlaqdNhz9QJZXfYe6L         Hold Tight  ...     -1.0       0.3
# 2997  3WVhkjB7Y4xFruqoCAajBb             Sue Me  ...      0.6       0.4
#
# [1000 rows x 25 columns]

# %%
personality4 = personality_q(spotify_partition4)
personality4

# %%
personality = pd.concat([personality, personality4], ignore_index=True)
personality
# Out:
#       artistic   emotion  imagination  ...  immoderation  self-conscious    stress
# 0     0.983429  0.269785     0.845684  ...      0.587846        0.719468  0.480640
# 1     0.951363  0.118000     0.993211  ...      0.801688        0.390560  0.443472
# 2     0.974373  0.406747     0.700611  ...      0.450389        0.736179  0.669987
# 3     0.945732  0.312331     0.866823  ...      0.532799        0.075188  0.109408
# 4     0.921820  0.017407     0.824431  ...      0.610249        0.098895  0.122751
# ...        ...       ...          ...  ...           ...             ...       ...
# 2993  0.997964  0.449819     0.846236  ...      0.276723        0.347574  0.144480
# 2994  0.989646  0.985677     0.414052  ...      0.607553        0.833457  0.876602
# 2995  0.974077  0.883346     0.404483  ...      0.389519        0.930596  0.948669
# 2996  0.997381  0.769346     0.966203  ...      0.539758        0.592168  0.467035
# 2997  0.903504  0.985776     0.295947  ...      0.826164        0.290433  0.844086
#
# [2998 rows x 17 columns]

# %%
spotify_partition5 = spotify_df.iloc[2998:4998,:]

# %%
personality5 = personality_q(spotify_partition5)
personality5

# %%
personality = pd.concat([personality, personality5], ignore_index=True)
personality
# Out:
#       artistic   emotion  imagination  ...  immoderation  self-conscious    stress
# 0     0.983429  0.269785     0.845684  ...      0.587846        0.719468  0.480640
# 1     0.951363  0.118000     0.993211  ...      0.801688        0.390560  0.443472
# 2     0.974373  0.406747     0.700611  ...      0.450389        0.736179  0.669987
# 3     0.945732  0.312331     0.866823  ...      0.532799        0.075188  0.109408
# 4     0.921820  0.017407     0.824431  ...      0.610249        0.098895  0.122751
# ...        ...       ...          ...  ...           ...             ...       ...
# 4993  0.842012  0.596860     0.932071  ...      0.116777        0.083433  0.096796
# 4994  0.794762  0.968778     0.611698  ...      0.672432        0.458051  0.210817
# 4995  0.991355  0.852482     0.999864  ...      0.910910        0.907188  0.423103
# 4996  0.993370  0.949072     0.871405  ...      0.522930        0.694173  0.593700
# 4997  0.407275  0.786887     0.783062  ...      0.737003        0.745947  0.305853
#
# [4998 rows x 17 columns]

# %%
spotify_partition6 = spotify_df.iloc[4998:13998,:]

# %%
personality6 = personality_q(spotify_partition6)
personality6

# %%
personality = pd.concat([personality, personality6], ignore_index=True)
personality
# Out:
#        artistic   emotion  imagination  ...  immoderation  self-conscious    stress
# 0      0.983429  0.269785     0.845684  ...      0.587846        0.719468  0.480640
# 1      0.951363  0.118000     0.993211  ...      0.801688        0.390560  0.443472
# 2      0.974373  0.406747     0.700611  ...      0.450389        0.736179  0.669987
# 3      0.945732  0.312331     0.866823  ...      0.532799        0.075188  0.109408
# 4      0.921820  0.017407     0.824431  ...      0.610249        0.098895  0.122751
# ...         ...       ...          ...  ...           ...             ...       ...
# 13993  0.566533  0.043130     0.883024  ...      0.616067        0.218735  0.123458
# 13994  0.982963  0.107937     0.722990  ...      0.384234        0.601002  0.200176
# 13995  0.977729  0.014555     0.940996  ...      0.884098        0.385182  0.114279
# 13996  0.747540  0.044445     0.970553  ...      0.946795        0.106488  0.306350
# 13997  0.868587  0.008722     0.902385  ...      0.693913        0.486329  0.115438
#
# [13998 rows x 17 columns]

# %%
spotify_partition7 = spotify_df.iloc[13998:24000,:]

# %%
personality7 = personality_q(spotify_partition7)
personality7

# %%
personality = pd.concat([personality, personality7], ignore_index=True)

# %%
personality = personality.iloc[:16634,:]
personality
# Out:
#        artistic   emotion  imagination  ...  immoderation  self-conscious    stress
# 0      0.983429  0.269785     0.845684  ...      0.587846        0.719468  0.480640
# 1      0.951363  0.118000     0.993211  ...      0.801688        0.390560  0.443472
# 2      0.974373  0.406747     0.700611  ...      0.450389        0.736179  0.669987
# 3      0.945732  0.312331     0.866823  ...      0.532799        0.075188  0.109408
# 4      0.921820  0.017407     0.824431  ...      0.610249        0.098895  0.122751
# ...         ...       ...          ...  ...           ...             ...       ...
# 16629  0.610572  0.497648     0.656574  ...      0.741312        0.739884  0.737564
# 16630  0.668308  0.458072     0.653067  ...      0.830509        0.727967  0.764861
# 16631  0.622659  0.528941     0.660484  ...      0.715226        0.741994  0.719494
# 16632  0.601383  0.542283     0.662385  ...      0.772645        0.730282  0.737626
# 16633  0.619835  0.467455     0.659438  ...      0.700599        0.741920  0.716462
#
# [16634 rows x 17 columns]

# %%
spotify_partition8 = spotify_df.iloc[16634:26734,:]
# Out:
#                            id               song  ... polarity magnitude
# 16634  0pfk4nldZlQbtDBi06Lupm           Snapchat  ...     -1.0       0.5
# 16635  0VnHW8YOpMzbob93AGljBM               Hola  ...     -1.0       0.2
# 16636  2C2TGgFzrTRIOdQS1vUN5h              Ginza  ...     -0.5       0.2
# 16637  5AxBtF5bpBeCem2Bq0Fwll          Solitario  ...      1.0       0.4
# 16638  18H4UlOn9dxEFkQ9kWBCVJ       35 Pa Las 12  ...      1.0       1.3
# ...                       ...                ...  ...      ...       ...
# 26729  0e0FMXCVBFcW2t3uVM90NJ     Simple Machine  ...     -1.0       0.9
# 26730  3ctly2pUS5Ot33CoKaxmgl        Expectation  ...     -1.0       0.3
# 26731  4C9C8sWHHTOsldu3TRZoKI            Gangway  ...     -1.0       0.7
# 26732  2C0GzDKThNKZr4thpolEzX         Kid Dreams  ...      1.0       0.2
# 26733  1a9KVNqNuMQUB8hgoC3xbf  Never Coming Down  ...     -1.0       0.5
#
# [10100 rows x 25 columns]

# %%
personality8 = personality_q(spotify_partition8)
personality8
# Out:
# ERROR:root:The number of words 96 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 96 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 6118dffe060e485e924c4c3f5862ddb0
# ERROR:root:The number of words 70 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 70 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 037d4bcfe8e9927689e01f62b3de9459
# ERROR:root:The number of words 41 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 41 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: cb4d1d161ff4cb8f4c643dece8b47d2e
# ERROR:root:The number of words 6 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 6 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 23e0e80e9220147fb9451a77bdff1696
# ERROR:root:The number of words 6 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 6 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 740ae19835b47a3caad215cb2d824c3a
# ERROR:root:The number of words 9 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 9 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 9db90d6380f4d6fe6ba5b9b5ecbba275
# ERROR:root:The number of words 60 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 60 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: fe365d319254c6187ab3406c324d5d55
# ERROR:root:The number of words 79 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 79 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 3f22937aef6be7e818a9bc3af4f4cd3d
# ERROR:root:The number of words 87 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 87 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 892f7fda86d39811249f5b63b02b1985
# ERROR:root:The number of words 96 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 96 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: d17b4900f5b095deb8aab0bfb0d3c1a8
# ERROR:root:The number of words 80 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 80 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 044caca96eea542a4452f9c8682206e8
# ERROR:root:The number of words 98 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 98 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 93e2f2dd2aa274529530bbee8898ac61
# ERROR:root:The number of words 56 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 56 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 224a014d9029f0fa1e92ee32c4df803f
# ERROR:root:The number of words 1 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 1 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 88ea21c826292e7c868c9e886305191f
# ERROR:root:The number of words 82 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 82 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 5a9ce5572484766cdfeea2cd2cb5d78b
# ERROR:root:The number of words 1 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 1 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 576b1c90a4a724268b1a33e4d0266b09
# ERROR:root:The number of words 77 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 77 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: dfd0a910a22140464041ab31a0151aba
# ERROR:root:The number of words 33 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 33 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 5fdbe709f672eda854686b2f196b8d0b
# ERROR:root:The number of words 44 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 44 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: aa2436eda7b0eb2fa8e44002a4a1dd2b
# ERROR:root:The number of words 94 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 94 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 601fcaa1d950fc8fc3f6d3bb178d5a86
# ERROR:root:The number of words 69 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 69 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: dacb50d23c0cb41fa066045da0e8e3b2
# ERROR:root:The number of words 41 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 41 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: abecb15edac7be3549c57ff3218f495b
# ERROR:root:The number of words 64 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 64 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 8c08d44c2edadff4c272f9dc5da08da2
# ERROR:root:The number of words 67 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 67 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 5a576c793ad25739719f63292399d7b8
# ERROR:root:The number of words 64 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 64 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 896bef3605335177f53692e3df224f64
# ERROR:root:The number of words 26 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 26 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 5756517e2e6f9311313d993ac67043b5
# ERROR:root:The number of words 61 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 61 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 37407677ed5ffc28256ca2bd0b1d707b
# ERROR:root:The number of words 30 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 30 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: f6bb7b52878ad68bc44aae632293acf0
# ERROR:root:The number of words 47 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 47 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: e1be7a4d6409b98a0d0fb6ab961bb5ab
# ERROR:root:The number of words 49 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 49 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 6a5dc2d5de95f5715cb8d840d157ba59
# ERROR:root:The number of words 46 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 46 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 6febdcb533626f670035fa74406cb7bc
# ERROR:root:The number of words 89 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 89 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 9b48ed1fad999c3be7d2385f8016d846
# ERROR:root:The number of words 99 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 99 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: ffecd514568ff6c5ea83ba8964f6e78c
# ERROR:root:The number of words 90 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 90 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 54c248ee0cdf5ad17d5ed2c8c6449b92
# ERROR:root:The number of words 13 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 13 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 35a7ec2d57ff54e588417116ac73fa9b
# ERROR:root:The number of words 79 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 79 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 760302935524cf158b653ab188503736
# ERROR:root:The number of words 26 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 26 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: fdf2ae061160e25a5e46d691154fedb8
# ERROR:root:The number of words 92 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 92 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: dd29d3d23c2084f487c092f2b44fcb45
# ERROR:root:The number of words 95 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 95 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 9091d2b733647698a90bf661f19e9657
# ERROR:root:The number of words 56 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 56 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 47d403be5146acd59d8c8e7e5f3aebce
# ERROR:root:The number of words 68 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 68 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: e986d749319ca439e232aa4b4d925405
# ERROR:root:The number of words 83 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 83 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 258cb39161908b0fc427991a56e20eb8
# ERROR:root:The number of words 92 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 92 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 000a29889aa70dae650959cf83e2675f
# ERROR:root:The number of words 92 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 92 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 6e21ed3065d4c72c70ad670e652102f7
# ERROR:root:The number of words 79 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 79 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: cc57d6f0ffe62183fee8ae7a4bb7026a
# ERROR:root:The number of words 53 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 53 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 4008d1d7e02048eb363447760bce832c
# ERROR:root:The number of words 81 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 81 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 6fc999ec7e4b8a1da29f91b1822bb054
# ERROR:root:The number of words 32 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 32 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 21f6ecbf1bc001fbe70decc8707b6d2f
# ERROR:root:The number of words 87 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 87 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 2f784563587438e58989129c63f4c453
# ERROR:root:The number of words 74 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 74 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: d9aa5ed6368e49923f42e7fbf296d5eb
# ERROR:root:The number of words 48 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 48 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 8944dde8da7f6627b09cf154e2f27e09
# ERROR:root:The number of words 37 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 37 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 4a10a07024141589d9673e64b84e0dd3
# ERROR:root:The number of words 40 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 40 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 851e0449970921b25bd5d2fa5e2aac83
# ERROR:root:The number of words 57 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 57 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 559c55100b7c5c7205395453857a23e2
# ERROR:root:The number of words 39 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 39 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 3d3eccddf7bcf0158cea9e13a18f75bc
# ERROR:root:The number of words 45 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 45 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: e5bcff3591f2cfbab7c1fc0b149b7ba1
# ERROR:root:The number of words 64 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 64 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 37d8681a72397579d7cc9575460e9150
# ERROR:root:The number of words 74 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 74 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: db9174655b2949878a90c5655e2e289f
# ERROR:root:The number of words 62 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 62 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 92d23721fd713e1a8be068b77e161fd8
# ERROR:root:The number of words 52 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 52 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 22df7d3c6d07bb42b7fa2581315e47b7
# ERROR:root:The number of words 76 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 76 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 95962651cf3b7bc5949a480e1a109e96
# ERROR:root:The number of words 87 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 87 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: d4374380ff0f6027e42c42b4bb7ed5cf
# ERROR:root:The number of words 99 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 99 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 175b11fc158028f18b0a742dbf9cc2b4
# ERROR:root:The number of words 77 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 77 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 5c257e3d4e843bbf4ffbdb51b2b66600
# ERROR:root:The number of words 35 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 35 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 4441691f315cf8576283475e1eb10e3a
# ERROR:root:The number of words 54 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 54 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 68760dc0de39bdb424c3597395332121
# ERROR:root:The number of words 45 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 45 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: ee6a42cb490021df82a9ad1c10d04be5
# ERROR:root:The number of words 89 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 89 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: d8b42ca17df9095718bac498485fd976
# ERROR:root:The number of words 64 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 64 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: aa1b1ce0cfc6d8eca2b98a14352c769a
# ERROR:root:The number of words 87 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 87 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 081a92b84d8a97c4ed0d38955627c51b
# ERROR:root:The number of words 66 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 66 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: ff3095136332c6f4da44bce5a48ea402
# ERROR:root:The number of words 90 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 90 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: f773112eae0f0ae3583547f4a2b649e3
# ERROR:root:The number of words 92 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 92 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 8014da5a6a28741430ff12bead219b37
# ERROR:root:The number of words 87 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 87 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: c21657da1d2d16bb31819691059b87c3
# ERROR:root:The number of words 92 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 92 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 99f44bfc290f2608af347649280929a9
# ERROR:root:The number of words 82 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 82 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 175c25647f71bfab64f18c91ea63c914
# ERROR:root:The number of words 89 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 89 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: b6e9d476251aeedd76f19418180280ab
# ERROR:root:The number of words 10 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 10 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: ab97df8ba1e8f79cdb2a1c4b1a8f6bbe
# ERROR:root:The number of words 44 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 44 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 5d76e5db3ced7a672f47df8721484137
# ERROR:root:The number of words 56 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 56 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 4500c5cc707490fd7c740cfb905f1637
# ERROR:root:The number of words 95 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 95 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 77c658697a255595964bb8cdf3fcc3eb
# ERROR:root:The number of words 65 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 65 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 13a7fdd1c687301ac22e7832c2c4ab40
# ERROR:root:The number of words 87 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 87 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 674c27906510e37e41cbd80262c73d67
# ERROR:root:The number of words 10 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 10 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 0f8ae21ceadc8821ffc3f2c78ee81aa9
# ERROR:root:The number of words 96 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 96 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 23c40b574ffb7438c0d6cdd0a5682ac8
# ERROR:root:The number of words 56 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 56 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 93be22b416dff0dd384dab1e87672b39
# ERROR:root:The number of words 45 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 45 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 30634d53af8e4b54147f50b000118c35
# ERROR:root:The number of words 53 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 53 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 295d6dccc12d77afc3f78726df22f2c1
# ERROR:root:The number of words 95 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 95 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 87eba8587f5a6d8cff02349ce07276db
# ERROR:root:The number of words 95 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 95 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 2d8677746b70e2653904278a36b8a91a
# ERROR:root:The number of words 56 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 56 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 9c3e3c863c27ea262f3a3305f2cec4fd
# ERROR:root:The number of words 49 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 49 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 9989db0ac5b2e1494f0bdf5ff9d2a1e7
# ERROR:root:The number of words 94 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
# ...
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 95 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: eef562a3f3d37c50739e18c905570fe9
# ERROR:root:The number of words 96 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 96 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 6dd405c72e8a7721588290d83a9d32ba
# ERROR:root:The number of words 33 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 33 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: c04dc7c3d523d0a6d0e9f437c53f0dd6
# ERROR:root:The number of words 98 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 98 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 35c6b4870e7831f186034f957b03fc39
# ERROR:root:The number of words 35 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 35 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 1475a90aeda610b4cb27a7ed8c39b007
# ERROR:root:The number of words 64 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 64 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: e66c0f72b0419ff14531403f5a638002
# ERROR:root:The number of words 56 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 56 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 7e997bcae0530e8886b6f486018c3c4f
# ERROR:root:The number of words 75 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 75 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 7bff765889ae023a8fad83bafb984651
# ERROR:root:The number of words 69 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 69 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: eee24b2cfb5f24b7f991449a87ac6889
# ERROR:root:The number of words 79 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 79 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: a58d839228e4bed98480dba82c28deb2
# ERROR:root:The number of words 69 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 69 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 2121f0dc6bbfe1c0e8a5aca309789924
# ERROR:root:The number of words 46 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 46 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: b3b103b41a6a0f6f34fe2c6fc4025992
# ERROR:root:The number of words 46 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 46 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: be9f14141f7ec4780f46918354d49a35
# ERROR:root:The number of words 91 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 91 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: c2443df14954bf1af288f26114435383
# ERROR:root:The number of words 73 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 73 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 2cb1bd1e65439014cbfbcfdfe9b950e3
# ERROR:root:The number of words 99 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 99 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 8a3f996a65dfd2d50a8aee48b512a1bf
# ERROR:root:The number of words 55 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 55 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 7f8eded0762018468a958a99ff2f93be
# ERROR:root:The number of words 87 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 87 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 452ed5afb913e834964b47e745b27a0f
# ERROR:root:The number of words 83 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 83 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: cb560ba9723228f1f6c583c09255cd2f
# ERROR:root:The number of words 87 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 87 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 1bbf9e95ed704491a9e4379ce67aab03
# ERROR:root:The number of words 94 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 94 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 22dc82d6ac2efa59e2eedd1d9fb8f4f6
# ERROR:root:The number of words 1 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 1 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 02eac042dcc2f603e79239407a5b5966
# ERROR:root:The number of words 42 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 42 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 56ec15b556c372c2d2d0c2c49e93ae49
# ERROR:root:The number of words 86 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 86 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 407df81821c029ee1ef90ed7dcacad7f
# ERROR:root:The number of words 80 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 80 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 5f27cceaec26babb16994511d8fe32d3
# ERROR:root:The number of words 90 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 90 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 93e7fd2103dc0cfa1e9c935a2a624931
# ERROR:root:The number of words 63 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 63 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 4a1c5489784e52b7eb6a3e686f2cd819
# ERROR:root:The number of words 68 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 68 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: a694982ddfa352ca0cd546556954903f
# ERROR:root:The number of words 63 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 63 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: e7c7546d2b212999a0086fdf64632c3e
#        artistic   emotion  imagination  ...  immoderation  self-conscious    stress
# 0      0.587477  0.507154     0.669622  ...      0.755667        0.725966  0.747313
# 1      0.593545  0.434140     0.677414  ...      0.697818        0.727110  0.715772
# 2      0.641673  0.425627     0.681010  ...      0.635098        0.727644  0.653994
# 3      0.588890  0.479982     0.669953  ...      0.688667        0.727523  0.711371
# 4      0.635742  0.411775     0.682576  ...      0.710038        0.751090  0.744855
# ...         ...       ...          ...  ...           ...             ...       ...
# 10095  0.483210  0.614466     0.791187  ...      0.367588        0.505668  0.712661
# 10096  0.999678  0.781936     0.994449  ...      0.477067        0.955391  0.976936
# 10097  0.999164  0.589154     0.999992  ...      0.943452        0.942651  0.640199
# 10098  0.975240  0.594793     0.909666  ...      0.518084        0.479072  0.334271
# 10099  0.798443  0.259770     0.705637  ...      0.574755        0.005545  0.004299
#
# [10100 rows x 17 columns]

# %%
personality
# Out:
#        artistic   emotion  imagination  ...  immoderation  self-conscious    stress
# 0      0.983429  0.269785     0.845684  ...      0.587846        0.719468  0.480640
# 1      0.951363  0.118000     0.993211  ...      0.801688        0.390560  0.443472
# 2      0.974373  0.406747     0.700611  ...      0.450389        0.736179  0.669987
# 3      0.945732  0.312331     0.866823  ...      0.532799        0.075188  0.109408
# 4      0.921820  0.017407     0.824431  ...      0.610249        0.098895  0.122751
# ...         ...       ...          ...  ...           ...             ...       ...
# 16629  0.610572  0.497648     0.656574  ...      0.741312        0.739884  0.737564
# 16630  0.668308  0.458072     0.653067  ...      0.830509        0.727967  0.764861
# 16631  0.622659  0.528941     0.660484  ...      0.715226        0.741994  0.719494
# 16632  0.601383  0.542283     0.662385  ...      0.772645        0.730282  0.737626
# 16633  0.619835  0.467455     0.659438  ...      0.700599        0.741920  0.716462
#
# [16634 rows x 17 columns]

# %%
personality = pd.concat([personality, personality8], ignore_index=True)
personality
# Out:
#        artistic   emotion  imagination  ...  immoderation  self-conscious    stress
# 0      0.983429  0.269785     0.845684  ...      0.587846        0.719468  0.480640
# 1      0.951363  0.118000     0.993211  ...      0.801688        0.390560  0.443472
# 2      0.974373  0.406747     0.700611  ...      0.450389        0.736179  0.669987
# 3      0.945732  0.312331     0.866823  ...      0.532799        0.075188  0.109408
# 4      0.921820  0.017407     0.824431  ...      0.610249        0.098895  0.122751
# ...         ...       ...          ...  ...           ...             ...       ...
# 26729  0.483210  0.614466     0.791187  ...      0.367588        0.505668  0.712661
# 26730  0.999678  0.781936     0.994449  ...      0.477067        0.955391  0.976936
# 26731  0.999164  0.589154     0.999992  ...      0.943452        0.942651  0.640199
# 26732  0.975240  0.594793     0.909666  ...      0.518084        0.479072  0.334271
# 26733  0.798443  0.259770     0.705637  ...      0.574755        0.005545  0.004299
#
# [26734 rows x 17 columns]

# %%
personality.to_csv("/content/drive/My Drive/personality.csv", index=False)

# %%
personality
# Out:
#        artistic   emotion  imagination  ...  immoderation  self-conscious    stress
# 0      0.983429  0.269785     0.845684  ...      0.587846        0.719468  0.480640
# 1      0.951363  0.118000     0.993211  ...      0.801688        0.390560  0.443472
# 2      0.974373  0.406747     0.700611  ...      0.450389        0.736179  0.669987
# 3      0.945732  0.312331     0.866823  ...      0.532799        0.075188  0.109408
# 4      0.921820  0.017407     0.824431  ...      0.610249        0.098895  0.122751
# ...         ...       ...          ...  ...           ...             ...       ...
# 26729  0.483210  0.614466     0.791187  ...      0.367588        0.505668  0.712661
# 26730  0.999678  0.781936     0.994449  ...      0.477067        0.955391  0.976936
# 26731  0.999164  0.589154     0.999992  ...      0.943452        0.942651  0.640199
# 26732  0.975240  0.594793     0.909666  ...      0.518084        0.479072  0.334271
# 26733  0.798443  0.259770     0.705637  ...      0.574755        0.005545  0.004299
#
# [26734 rows x 17 columns]

# %% [markdown]
# **My data for personality analysis so far only goes back to 2015, but I have run out of API calls to use towards IBM Cloud Personality Insights.**

# %%
spotify_df.iloc[:26734,:]
# Out:
#                            id               song  ... polarity magnitude
# 0      0Veyvc3n9AcLSoK3r1dA12  Voices In My Head  ...     -1.0       1.4
# 1      77JzXZonNumWsuXKy9vr3U             Beasty  ...      0.0       1.5
# 2      18yllZD0TdF7ykcREib8Z1           I Did It  ...     -1.0       1.9
# 3      1wJRveJZLSb1rjhnUHQiv6            Swervin  ...      0.5       1.4
# 4      0jAfdqv18goRTUxm3ilRjb         Startender  ...     -1.0       2.5
# ...                       ...                ...  ...      ...       ...
# 26729  0e0FMXCVBFcW2t3uVM90NJ     Simple Machine  ...     -1.0       0.9
# 26730  3ctly2pUS5Ot33CoKaxmgl        Expectation  ...     -1.0       0.3
# 26731  4C9C8sWHHTOsldu3TRZoKI            Gangway  ...     -1.0       0.7
# 26732  2C0GzDKThNKZr4thpolEzX         Kid Dreams  ...      1.0       0.2
# 26733  1a9KVNqNuMQUB8hgoC3xbf  Never Coming Down  ...     -1.0       0.5
#
# [26734 rows x 25 columns]

# %%
spotify_complete = spotify_df.iloc[:26734,:].merge(personality, left_index=True,
                                right_index=True, how="outer")
spotify_complete
# Out:
#                            id               song  ... self-conscious    stress
# 0      0Veyvc3n9AcLSoK3r1dA12  Voices In My Head  ...       0.719468  0.480640
# 1      77JzXZonNumWsuXKy9vr3U             Beasty  ...       0.390560  0.443472
# 2      18yllZD0TdF7ykcREib8Z1           I Did It  ...       0.736179  0.669987
# 3      1wJRveJZLSb1rjhnUHQiv6            Swervin  ...       0.075188  0.109408
# 4      0jAfdqv18goRTUxm3ilRjb         Startender  ...       0.098895  0.122751
# ...                       ...                ...  ...            ...       ...
# 26729  0e0FMXCVBFcW2t3uVM90NJ     Simple Machine  ...       0.505668  0.712661
# 26730  3ctly2pUS5Ot33CoKaxmgl        Expectation  ...       0.955391  0.976936
# 26731  4C9C8sWHHTOsldu3TRZoKI            Gangway  ...       0.942651  0.640199
# 26732  2C0GzDKThNKZr4thpolEzX         Kid Dreams  ...       0.479072  0.334271
# 26733  1a9KVNqNuMQUB8hgoC3xbf  Never Coming Down  ...       0.005545  0.004299
#
# [26734 rows x 42 columns]

# %%
spotify_complete = spotify_complete[spotify_complete["artistic"].notnull()]
spotify_complete = spotify_complete.reset_index().iloc[:,1:]
spotify_complete
# Out:
#                            id               song  ... self-conscious    stress
# 0      0Veyvc3n9AcLSoK3r1dA12  Voices In My Head  ...       0.719468  0.480640
# 1      77JzXZonNumWsuXKy9vr3U             Beasty  ...       0.390560  0.443472
# 2      18yllZD0TdF7ykcREib8Z1           I Did It  ...       0.736179  0.669987
# 3      1wJRveJZLSb1rjhnUHQiv6            Swervin  ...       0.075188  0.109408
# 4      0jAfdqv18goRTUxm3ilRjb         Startender  ...       0.098895  0.122751
# ...                       ...                ...  ...            ...       ...
# 25457  0e0FMXCVBFcW2t3uVM90NJ     Simple Machine  ...       0.505668  0.712661
# 25458  3ctly2pUS5Ot33CoKaxmgl        Expectation  ...       0.955391  0.976936
# 25459  4C9C8sWHHTOsldu3TRZoKI            Gangway  ...       0.942651  0.640199
# 25460  2C0GzDKThNKZr4thpolEzX         Kid Dreams  ...       0.479072  0.334271
# 25461  1a9KVNqNuMQUB8hgoC3xbf  Never Coming Down  ...       0.005545  0.004299
#
# [25462 rows x 42 columns]

# %%
spotify_complete["explicit"] = spotify_complete["explicit"].astype("int64")
spotify_complete = spotify_complete.drop("duration_ms", axis=1)
spotify_complete
# Out:
#                            id               song  ... self-conscious    stress
# 0      0Veyvc3n9AcLSoK3r1dA12  Voices In My Head  ...       0.719468  0.480640
# 1      77JzXZonNumWsuXKy9vr3U             Beasty  ...       0.390560  0.443472
# 2      18yllZD0TdF7ykcREib8Z1           I Did It  ...       0.736179  0.669987
# 3      1wJRveJZLSb1rjhnUHQiv6            Swervin  ...       0.075188  0.109408
# 4      0jAfdqv18goRTUxm3ilRjb         Startender  ...       0.098895  0.122751
# ...                       ...                ...  ...            ...       ...
# 25457  0e0FMXCVBFcW2t3uVM90NJ     Simple Machine  ...       0.505668  0.712661
# 25458  3ctly2pUS5Ot33CoKaxmgl        Expectation  ...       0.955391  0.976936
# 25459  4C9C8sWHHTOsldu3TRZoKI            Gangway  ...       0.942651  0.640199
# 25460  2C0GzDKThNKZr4thpolEzX         Kid Dreams  ...       0.479072  0.334271
# 25461  1a9KVNqNuMQUB8hgoC3xbf  Never Coming Down  ...       0.005545  0.004299
#
# [25462 rows x 41 columns]

# %%
spotify_complete["date"] = pd.to_datetime(spotify_complete["date"])
spotify_complete["date"]
# Out:
# 0       2018-12-21
# 1       2018-12-21
# 2       2018-12-21
# 3       2018-12-21
# 4       2018-12-21
#            ...
# 25457   2015-01-13
# 25458   2015-01-13
# 25459   2015-01-13
# 25460   2015-01-13
# 25461   2015-01-13
# Name: date, Length: 25462, dtype: datetime64[ns]

# %%
spotify_complete.to_csv("/content/drive/My Drive/spotify_complete.csv", index=False)
